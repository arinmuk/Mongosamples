# %%
import sys
import pandas as pd
import pyodbc as pyodbc
from sqlalchemy.dialects.mssql import pymssql
import pymssql
import pymongo
import csv
import json
from config import userid,password
from pymongo import MongoClient
from flask import Flask, jsonify, render_template
client = MongoClient()
client = MongoClient('localhost', 27017)
#mongodb+srv://arinmuk:amarji123!@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority
cloudstr=f'mongodb+srv://{userid}:{password}@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority'
cloudclient = MongoClient(cloudstr)

# %%
localdb= client['nasa']
localcolimages= localdb['images_of_day']
cursor = localcolimages.find()
localimagesdf= pd.DataFrame(list( localcolimages.find()))
localimagesdf.head()
# Out:
#                         _id   code copyright        date  \
# 0  5e178e4cd16abd1828afe837  400.0       NaN         NaN
# 1  5e178e4cd16abd1828afe838    NaN       NaN  1995-06-16
# 2  5e178e4dd16abd1828afe839  500.0       NaN         NaN
# 3  5e178e4dd16abd1828afe83a  500.0       NaN         NaN
# 4  5e178e4dd16abd1828afe83b  500.0       NaN         NaN
#
#                                          explanation  \
# 0                                                NaN
# 1  Today's Picture:    Explanation:  If the Earth...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          hdurl media_type  \
# 0                                          NaN        NaN
# 1  https://apod.nasa.gov/apod/image/e_lens.gif      image
# 2                                          NaN        NaN
# 3                                          NaN        NaN
# 4                                          NaN        NaN
#
#                                                  msg service_version  \
# 0  Date must be between Jun 16, 1995 and Jan 09, ...              v1
# 1                                                NaN              v1
# 2                             Internal Service Error              v1
# 3                             Internal Service Error              v1
# 4                             Internal Service Error              v1
#
#                 title                                          url
# 0                 NaN                                          NaN
# 1  Neutron Star Earth  https://apod.nasa.gov/apod/image/e_lens.gif
# 2                 NaN                                          NaN
# 3                 NaN                                          NaN
# 4                 NaN                                          NaN

# %%
clouddb= cloudclient['nasa']
cloudcolimages= clouddb['images_of_day']
cloudcolimages.insert_many(localimagesdf.to_dict('records'))
